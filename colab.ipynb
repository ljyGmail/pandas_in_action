# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PROJ_path = "/content/drive/MyDrive/Workspace/pandas_in_action/"
# %cd "{PROJ_path}"
# %pwd
# Out:
# /content/drive/MyDrive/Workspace/pandas_in_action
# '/content/drive/MyDrive/Workspace/pandas_in_action'

# %%
with open(PROJ_path + 'requirements.txt', 'r') as f:
  content = f.read()
print(content.split('\n')[:3])
# Out:
# ['anyio==3.7.1', 'argon2-cffi==23.1.0', 'argon2-cffi-bindings==21.2.0']

# %%
# !git config user.name 'ljyColab'
# !git config user.email 'liangjy881@gmail.com'

# %%
# !git config --list | grep user.name
# Out:
# user.name=ljyColab

# %%
# !git config --list | grep user.email
# Out:
# user.email=liangjy881@gmail.com

# %%
# !git status
# Out:
# Refresh index: 100% (56/56), done.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	colab.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   colab.ipynb

# %%
# !git commit -m "commit from colab"
# Out:
# [main 324915a] commit from colab
#  1 file changed, 1 insertion(+)
#  create mode 100644 colab.ipynb

# %%
# !git log --oneline --graph --all | head -n 5
# Out:
# * 324915a commit from colab
# * 5628332 14.4 pie charts
# * ed71335 14.3 bar graphs
# * 47df146 14.2 line charts
# * 6eeea7d 13.5 option context

# %%
# !git push origin main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.38 KiB | 354.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/ljyGmail/pandas_in_action.git
#    5628332..324915a  main -> main
