# %% [markdown]
# # Chapter 10: Merging, joining, and concatenating

# %% [markdown]
# ## 10.1 Introducing the data sets

# %%
import pandas as pd

# %%
groups1 = pd.read_csv("data/ch10/meetup/groups1.csv")
groups1.head()
# Out:
#    group_id                           name  category_id  city_id
# 0      6388         Alternative Health NYC           14    10001
# 1      6510      Alternative Energy Meetup            4    10001
# 2      8458              NYC Animal Rights           26    10001
# 3      8940  The New York City Anime Group           29    10001
# 4     10104             NYC Pit Bull Group           26    10001

# %%
groups2 = pd.read_csv("data/ch10/meetup/groups2.csv")
groups2.head()
# Out:
#    group_id                                               name  category_id  \
# 0  18879327                                       BachataMania            5
# 1  18880221  Photoshoot Chicago - Photography and Modeling ...           27
# 2  18880426  Chicago Adult Push / Kick Scooter Group Riding...           31
# 3  18880495                  Chicago International Soccer Club           32
# 4  18880695                   Impact.tech San Francisco Meetup            2
#
#    city_id
# 0    10001
# 1    60601
# 2    60601
# 3    60601
# 4    94101

# %%
categories = pd.read_csv("data/ch10/meetup/categories.csv")
categories.head()
# Out:
#    category_id            category_name
# 0            1           Arts & Culture
# 1            3       Cars & Motorcycles
# 2            4  Community & Environment
# 3            5                  Dancing
# 4            6     Education & Learning

# %%
pd.read_csv("data/ch10/meetup/cities.csv").head()
# Out:
#       id            city state    zip
# 0   7093   West New York    NJ   7093
# 1  10001        New York    NY  10001
# 2  13417  New York Mills    NY  13417
# 3  46312    East Chicago    IN  46312
# 4  56567  New York Mills    MN  56567

# %%
cities = pd.read_csv(
    "data/ch10/meetup/cities.csv", dtype={"zip": "string"}
)

cities.head()
# Out:
#       id            city state    zip
# 0   7093   West New York    NJ  07093
# 1  10001        New York    NY  10001
# 2  13417  New York Mills    NY  13417
# 3  46312    East Chicago    IN  46312
# 4  56567  New York Mills    MN  56567

# %% [markdown]
# ## 10.2 Concatenating data sets

# %%
pd.concat(objs=[groups1, groups2])
# Out:
#       group_id                                               name  \
# 0         6388                             Alternative Health NYC
# 1         6510                          Alternative Energy Meetup
# 2         8458                                  NYC Animal Rights
# 3         8940                      The New York City Anime Group
# 4        10104                                 NYC Pit Bull Group
# ...        ...                                                ...
# 8326  26377464                                            Shinect
# 8327  26377698  The art of getting what you want [conference s...
# 8328  26378067                        Streeterville Running Group
# 8329  26378128                                     Just Dance NYC
# 8330  26378470           FREE Arabic Chicago Evanston North Burbs
#
#       category_id  city_id
# 0              14    10001
# 1               4    10001
# 2              26    10001
# 3              29    10001
# 4              26    10001
# ...

# %%
len(groups1)
# Out:
# 7999

# %%
len(groups2)
# Out:
# 8331

# %%
len(groups1) + len(groups2)
# Out:
# 16330

# %%
pd.concat(objs=[groups1, groups2], ignore_index=True)
# Out:
#        group_id                                               name  \
# 0          6388                             Alternative Health NYC
# 1          6510                          Alternative Energy Meetup
# 2          8458                                  NYC Animal Rights
# 3          8940                      The New York City Anime Group
# 4         10104                                 NYC Pit Bull Group
# ...         ...                                                ...
# 16325  26377464                                            Shinect
# 16326  26377698  The art of getting what you want [conference s...
# 16327  26378067                        Streeterville Running Group
# 16328  26378128                                     Just Dance NYC
# 16329  26378470           FREE Arabic Chicago Evanston North Burbs
#
#        category_id  city_id
# 0               14    10001
# 1                4    10001
# 2               26    10001
# 3               29    10001
# ...

# %%
pd.concat(objs=[groups1, groups2], keys=["G1", "G2"])
# Out:
#          group_id                                               name  \
# G1 0         6388                             Alternative Health NYC
#    1         6510                          Alternative Energy Meetup
#    2         8458                                  NYC Animal Rights
#    3         8940                      The New York City Anime Group
#    4        10104                                 NYC Pit Bull Group
# ...           ...                                                ...
# G2 8326  26377464                                            Shinect
#    8327  26377698  The art of getting what you want [conference s...
#    8328  26378067                        Streeterville Running Group
#    8329  26378128                                     Just Dance NYC
#    8330  26378470           FREE Arabic Chicago Evanston North Burbs
#
#          category_id  city_id
# G1 0              14    10001
#    1               4    10001
#    2              26    10001
# ...

# %%
groups = pd.concat(objs=[groups1, groups2], ignore_index=True)

# %% [markdown]
# ## 10.3 Missing values in concatenated DataFrames

# %%
sports_champions_A = pd.DataFrame(
    data=[
        ["New England Patriots", "Huston Astros"],
        ["Philadellphia Eagles", "Boston Red Sox"]
    ],
    columns=["Football", "Baseball"],
    index=[2017, 2018]
)

sports_champions_A
# Out:
#                   Football        Baseball
# 2017  New England Patriots   Huston Astros
# 2018  Philadellphia Eagles  Boston Red Sox

# %%
sports_champions_B = pd.DataFrame(
    data=[
        ["New England Patriots", "St. Louis Blues"],
        ["Kansas City Chiefs", "Tampa Bay Lightning"]
    ],
    columns=["Football", "Hockey"],
    index=[2019, 2020]
)

sports_champions_B
# Out:
#                   Football               Hockey
# 2019  New England Patriots      St. Louis Blues
# 2020    Kansas City Chiefs  Tampa Bay Lightning

# %%
pd.concat(objs=[sports_champions_A, sports_champions_B])
# Out:
#                   Football        Baseball               Hockey
# 2017  New England Patriots   Huston Astros                  NaN
# 2018  Philadellphia Eagles  Boston Red Sox                  NaN
# 2019  New England Patriots             NaN      St. Louis Blues
# 2020    Kansas City Chiefs             NaN  Tampa Bay Lightning

# %%
sports_champions_C = pd.DataFrame(
    data=[
        ["Piisttsburgh Penguins", "Golden State Worriors"],
        ["Washington Capitals", "Golden State Worriors"]
    ],
    columns=["Hockey", "Basketball"],
    index=[2017, 2018]
)

sports_champions_C
# Out:
#                      Hockey             Basketball
# 2017  Piisttsburgh Penguins  Golden State Worriors
# 2018    Washington Capitals  Golden State Worriors

# %%
pd.concat(objs=[sports_champions_A, sports_champions_C])
# Out:
#                   Football        Baseball                 Hockey  \
# 2017  New England Patriots   Huston Astros                    NaN
# 2018  Philadellphia Eagles  Boston Red Sox                    NaN
# 2017                   NaN             NaN  Piisttsburgh Penguins
# 2018                   NaN             NaN    Washington Capitals
#
#                  Basketball
# 2017                    NaN
# 2018                    NaN
# 2017  Golden State Worriors
# 2018  Golden State Worriors

# %%
# The two lines below are equivalent
pd.concat(
    objs=[sports_champions_A, sports_champions_C],
    axis=1
)

pd.concat(
    objs=[sports_champions_A, sports_champions_C],
    axis="columns"
)
# Out:
#                   Football        Baseball                 Hockey  \
# 2017  New England Patriots   Huston Astros  Piisttsburgh Penguins
# 2018  Philadellphia Eagles  Boston Red Sox    Washington Capitals
#
#                  Basketball
# 2017  Golden State Worriors
# 2018  Golden State Worriors

# %% [markdown]
# ## 10.4 Left joins

# %%
groups.head(3)
# Out:
#    group_id                       name  category_id  city_id
# 0      6388     Alternative Health NYC           14    10001
# 1      6510  Alternative Energy Meetup            4    10001
# 2      8458          NYC Animal Rights           26    10001

# %%
categories.head(3)
# Out:
#    category_id            category_name
# 0            1           Arts & Culture
# 1            3       Cars & Motorcycles
# 2            4  Community & Environment

# %%
groups.merge(categories, how="left", on="category_id").head()
# Out:
#    group_id                           name  category_id  city_id  \
# 0      6388         Alternative Health NYC           14    10001
# 1      6510      Alternative Energy Meetup            4    10001
# 2      8458              NYC Animal Rights           26    10001
# 3      8940  The New York City Anime Group           29    10001
# 4     10104             NYC Pit Bull Group           26    10001
#
#              category_name
# 0       Health & Wellbeing
# 1  Community & Environment
# 2                      NaN
# 3         Sci-Fi & Fantasy
# 4                      NaN

# %% [markdown]
# ## 10.5 Inner joins

# %%
groups.head(3)
# Out:
#    group_id                       name  category_id  city_id
# 0      6388     Alternative Health NYC           14    10001
# 1      6510  Alternative Energy Meetup            4    10001
# 2      8458          NYC Animal Rights           26    10001

# %%
categories.head(3)
# Out:
#    category_id            category_name
# 0            1           Arts & Culture
# 1            3       Cars & Motorcycles
# 2            4  Community & Environment

# %%
groups.merge(categories, how="inner", on="category_id")
# Out:
#       group_id                                        name  category_id  \
# 0         6388                      Alternative Health NYC           14
# 1        54126                          Energy Healers NYC           14
# 2        67776                     Flourishing Life Meetup           14
# 3       111855      Hypnosis & NLP NYC - Update Your Brain           14
# 4       129277             The Live Food Chicago Community           14
# ...        ...                                         ...          ...
# 8032  25536270       New York Cuckold Relationships Meetup           17
# 8033  25795045  Pagans Paradise NYC - A Haven for Heathens           17
# 8034  25856573                 Fuck Yeah Femme Productions           17
# 8035  26158102                 Chicago Crossdresser Meetup           17
# 8036  26219043                    Corporate Goes Conscious           17
#
#       city_id       category_name
# 0       10001  Health & Wellbeing
# ...

# %%
groups[groups["category_id"] == 14]
# Out:
#        group_id                                               name  \
# 0          6388                             Alternative Health NYC
# 52        54126                                 Energy Healers NYC
# 78        67776                            Flourishing Life Meetup
# 121      111855             Hypnosis & NLP NYC - Update Your Brain
# 136      129277                    The Live Food Chicago Community
# ...         ...                                                ...
# 16174  26291539  The Transformation Project: Collaborative Life...
# 16201  26299876  Cognitive Empathy, How To Translate Enemy Imag...
# 16248  26322976                      Contemplative Practices Group
# 16314  26366221     The art of getting what you want: hacking fear
# 16326  26377698  The art of getting what you want [conference s...
#
#        category_id  city_id
# 0               14    10001
# 52              14    10001
# 78              14    10001
# 121             14    10001
# ...

# %%
categories[categories["category_id"] == 14]
# Out:
#    category_id       category_name
# 8           14  Health & Wellbeing

# %% [markdown]
# ## 10.6 Outer joins

# %%
groups.head(3)
# Out:
#    group_id                       name  category_id  city_id
# 0      6388     Alternative Health NYC           14    10001
# 1      6510  Alternative Energy Meetup            4    10001
# 2      8458          NYC Animal Rights           26    10001

# %%
cities.head(3)
# Out:
#       id            city state    zip
# 0   7093   West New York    NJ  07093
# 1  10001        New York    NY  10001
# 2  13417  New York Mills    NY  13417

# %%
groups.merge(
    cities, how="outer", left_on="city_id", right_on="id"
)
# Out:
#          group_id                                     name  category_id  \
# 0          6388.0                   Alternative Health NYC         14.0
# 1          6510.0                Alternative Energy Meetup          4.0
# 2          8458.0                        NYC Animal Rights         26.0
# 3          8940.0            The New York City Anime Group         29.0
# 4         10104.0                       NYC Pit Bull Group         26.0
# ...           ...                                      ...          ...
# 16329  24303427.0  Midwest FPGA/AI/Machine Learning Meetup         34.0
# 16330         NaN                                      NaN          NaN
# 16331         NaN                                      NaN          NaN
# 16332         NaN                                      NaN          NaN
# 16333         NaN                                      NaN          NaN
#
#        city_id     id            city state    zip
# 0      10001.0  10001        New York    NY  10001
# ...

# %%
groups.merge(
    cities,
    how="outer",
    left_on="city_id",
    right_on="id",
    indicator=True
)
# Out:
#          group_id                                     name  category_id  \
# 0          6388.0                   Alternative Health NYC         14.0
# 1          6510.0                Alternative Energy Meetup          4.0
# 2          8458.0                        NYC Animal Rights         26.0
# 3          8940.0            The New York City Anime Group         29.0
# 4         10104.0                       NYC Pit Bull Group         26.0
# ...           ...                                      ...          ...
# 16329  24303427.0  Midwest FPGA/AI/Machine Learning Meetup         34.0
# 16330         NaN                                      NaN          NaN
# 16331         NaN                                      NaN          NaN
# 16332         NaN                                      NaN          NaN
# 16333         NaN                                      NaN          NaN
#
#        city_id     id            city state    zip      _merge
# ...

# %%
outer_join = groups.merge(
    cities,
    how="outer",
    left_on="city_id",
    right_on="id",
    indicator=True
)

in_right_only = outer_join["_merge"] == "right_only"

outer_join[in_right_only].head()
# Out:
#        group_id name  category_id  city_id     id            city state  \
# 16330       NaN  NaN          NaN      NaN  13417  New York Mills    NY
# 16331       NaN  NaN          NaN      NaN  46312    East Chicago    IN
# 16332       NaN  NaN          NaN      NaN  56567  New York Mills    MN
# 16333       NaN  NaN          NaN      NaN  95712    Chicago Park    CA
#
#          zip      _merge
# 16330  13417  right_only
# 16331  46312  right_only
# 16332  56567  right_only
# 16333  95712  right_only

# %% [markdown]
# ## 10.7 Merging on index labels

# %%
cities.head(3)
# Out:
#       id            city state    zip
# 0   7093   West New York    NJ  07093
# 1  10001        New York    NY  10001
# 2  13417  New York Mills    NY  13417

# %%
cities = cities.set_index("id")

# %%
cities.head(3)
# Out:
#                  city state    zip
# id
# 7093    West New York    NJ  07093
# 10001        New York    NY  10001
# 13417  New York Mills    NY  13417

# %%
groups.head(3)
# Out:
#    group_id                       name  category_id  city_id
# 0      6388     Alternative Health NYC           14    10001
# 1      6510  Alternative Energy Meetup            4    10001
# 2      8458          NYC Animal Rights           26    10001

# %%
groups.merge(
    cities,
    how="left",
    left_on="city_id",
    right_index=True
)
# Out:
#        group_id                                               name  \
# 0          6388                             Alternative Health NYC
# 1          6510                          Alternative Energy Meetup
# 2          8458                                  NYC Animal Rights
# 3          8940                      The New York City Anime Group
# 4         10104                                 NYC Pit Bull Group
# ...         ...                                                ...
# 16325  26377464                                            Shinect
# 16326  26377698  The art of getting what you want [conference s...
# 16327  26378067                        Streeterville Running Group
# 16328  26378128                                     Just Dance NYC
# 16329  26378470           FREE Arabic Chicago Evanston North Burbs
#
#        category_id  city_id           city state    zip
# 0               14    10001       New York    NY  10001
# ...

# %% [markdown]
# ## 10.8 Coding challenge

# %% [markdown]
# ### 10.8.1 Problems

# %%
pd.read_csv("data/ch10/restaurant/week_1_sales.csv").head()
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1
# 3          202        2
# 4          155        9

# %%
week1 = pd.read_csv("data/ch10/restaurant/week_1_sales.csv")
week2 = pd.read_csv("data/ch10/restaurant/week_2_sales.csv")

# %%
pd.read_csv("data/ch10/restaurant/customers.csv", index_col="ID").head()
# Out:
#    First Name Last Name  Gender  Company                     Occupation
# ID
# 1      Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 2    Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 3       Roger     Black    Male  Tagfeed              Account Executive
# 4      Steven     Evans    Male     Fatz               Registered Nurse
# 5        Judy  Morrison  Female  Demivee                Legal Assistant

# %%
customers = pd.read_csv(
    "data/ch10/restaurant/customers.csv", index_col="ID"
)

# %%
pd.read_csv("data/ch10/restaurant/foods.csv", index_col="Food ID")
# Out:
#           Food Item  Price
# Food ID
# 1             Sushi   3.99
# 2           Burrito   9.99
# 3              Taco   2.99
# 4        Quesadilla   4.25
# 5             Pizza   2.49
# 6             Pasta  13.99
# 7             Steak  24.99
# 8             Salad  11.25
# 9             Donut   0.99
# 10            Drink   1.75

# %%
foods = pd.read_csv("data/ch10/restaurant/foods.csv", index_col="Food ID")

# %% [markdown]
# ### 10.8.2 Solutions

# %%
# 1. Concatenate the two weeks of sales data into one DataFrame. 
# Assign the week1 DataFrame a key of "Week 1" and the week2 DataFrame a key of "Week 2".
pd.concat(objs=[week1, week2], keys=["Week 1", "Week 2"])
# Out:
#             Customer ID  Food ID
# Week 1 0            537        9
#        1             97        4
#        2            658        1
#        3            202        2
#        4            155        9
# ...                 ...      ...
# Week 2 245          783       10
#        246          556       10
#        247          547        9
#        248          252        9
#        249          249        6
#
# [500 rows x 2 columns]

# %%
# 2. Find the customers who ate at the restaurant both weeks.
week1.merge(right=week2, how="inner", on="Customer ID").head()
# Out:
#    Customer ID  Food ID_x  Food ID_y
# 0          537          9          5
# 1          155          9          3
# 2          155          1          3
# 3          503          5          8
# 4          503          5          9

# %%
# remove duplicates
week1.merge(
    right=week2, how="inner", on="Customer ID"
).drop_duplicates(subset=["Customer ID"]).head()
# Out:
#    Customer ID  Food ID_x  Food ID_y
# 0          537          9          5
# 1          155          9          3
# 3          503          5          8
# 5          550          6          7
# 6          101          7          4

# %%
# 3. Find the customers who ate at the restaurant both weeks and ordered the same item each week.
# Hint: You can join data sets on multiple columns b passing the on parameter a list of columns.
week1.merge(
    right=week2,
    how="inner",
    on=["Customer ID", "Food ID"]
)
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
# 4. Identify which customers came in only on Week 1 and only on Week 2.
week1.merge(
    right=week2,
    how="outer",
    on="Customer ID",
    indicator=True
).head()
# Out:
#    Customer ID  Food ID_x  Food ID_y     _merge
# 0          537        9.0        5.0       both
# 1           97        4.0        NaN  left_only
# 2          658        1.0        NaN  left_only
# 3          202        2.0        NaN  left_only
# 4          155        9.0        3.0       both

# %%
# 5. Each row in the week1 DataFrame identifies a customer who purchased a food item.
# For each row, pull in the customer's information from the customers DataFrame.
week1.merge(
    right=customers,
    how="left",
    left_on="Customer ID",
    right_index=True
).head()
# Out:
#    Customer ID  Food ID First Name Last Name  Gender    Company  \
# 0          537        9     Cheryl   Carroll  Female   Zoombeat
# 1           97        4     Amanda   Watkins  Female        Ozu
# 2          658        1    Patrick      Webb    Male  Browsebug
# 3          202        2      Louis  Campbell    Male  Rhynoodle
# 4          155        9    Carolyn      Diaz  Female   Gigazoom
#
#                       Occupation
# 0               Registered Nurse
# 1            Account Coordinator
# 2  Community Outreach Specialist
# 3     Account Representative III
# 4     Database Administrator III
